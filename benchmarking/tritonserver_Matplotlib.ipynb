# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4, 5, 6, 7]

amp = ["68.13", "112.62", "162.51", "165.08", "182.82", "185.74", "223.17"]
trt = ["45.01", "66.32", "84.23", "100.69", "115.00", "129.79", "133.08"]


plt.plot(
    x, [float(i.replace("k", "e3")) for i in amp], label="Automaitc-mixed-precision"
)
plt.plot(x, [float(i.replace("k", "e3")) for i in trt], label="TensortRT")

plt.xlabel("Number of GPUs")
plt.ylabel("Throughput (tiles/sec)")
plt.legend()
plt.title(
    "Automatic-mixed-precision VS tensorRT-FP16 (max_Batch_size:128, gpu_count:1) "
)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np


labels = ["256", "512", "1024", "2048"]

gRPC = [61785.6, 85458.4, 102997.7, 112030.1]
HTTP = [824.8, 867.4, 879.0, 851.4]


x = np.arange(len(labels))  # the label locations
width = 0.20  # the width of the bars


fig, ax = plt.subplots()

rects1 = ax.bar(x - width / 2, gRPC, width, label="gRPC")
rects2 = ax.bar(x + width / 2, HTTP, width, label="HTTP")


# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel("Throughput")
ax.set_xlabel("Batches")
ax.set_title("Impact of protocol and Batch size (gRPC Vs HTTP)")
ax.set_xticks(x, labels)
ax.legend()

ax.bar_label(rects1, padding=1, fontsize=10)
ax.bar_label(rects2, padding=6, fontsize=10)


fig.tight_layout()

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np


labels = ["256", "512", "1024", "2048"]

gRPC = [61785.6, 85458.4, 102997.7, 112030.1]
gRPC_C = [3242.59, 3569.10, 3912.77, 4062.22]
HTTP = [824.8, 867.4, 879.0, 851.4]
HTTP_C = [835.37, 863.61, 871.52, 848.52]


x = np.arange(len(labels))  # the label locations
width = 0.20  # the width of the bars


fig, ax = plt.subplots()

rects1 = ax.bar(x - width / 2, gRPC, width, label="gRPC")
rects3 = ax.bar(x + width * 1.5, gRPC_C, width, label="gRPC Compression")
rects2 = ax.bar(x + width / 2, HTTP, width, label="HTTP")
rects4 = ax.bar(x + width * 2.5, HTTP_C, width, label="HTTP Compression")


# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel("Throughput")
ax.set_xlabel("Batches")
ax.set_title("Impact of protocol and Batch size with Compression (gRPC Vs HTTP)")
ax.set_xticks(x, labels)
ax.legend(prop={"size": 8})

ax.bar_label(rects1, padding=1, fontsize=6)
ax.bar_label(rects2, padding=6, fontsize=6)
ax.bar_label(rects3, padding=12, fontsize=6)
ax.bar_label(rects4, padding=1, fontsize=6)


fig.tight_layout()

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np


labels = ["256", "512", "1024", "2048"]
single_instance = [61785, 85458, 102997, 112030]
two_instance = [55496, 84537, 110532, 112448]
four_instance = [58557, 79549, 109040, 122993]
eigth_instance = [55248, 87005, 100342, 123298]

x = np.arange(len(labels))  # the label locations
width = 0.20  # the width of the bars


fig, ax = plt.subplots()

rects1 = ax.bar(x - width / 2, single_instance, width, label="1 Instance")
rects2 = ax.bar(x + width / 2, two_instance, width, label="2 Instance")
rects3 = ax.bar(x + width * 1.5, four_instance, width, label="4 Instance")
rects4 = ax.bar(x + width * 2.5, eigth_instance, width, label="8 Instance")


# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel("Throughput")
ax.set_xlabel("Batches")
ax.set_title("Impact of number of model instances with batches (gRPC)")
ax.set_xticks(x, labels)
ax.legend()

ax.bar_label(rects1, padding=1, fontsize=6)
ax.bar_label(rects2, padding=6, fontsize=6)
ax.bar_label(rects3, padding=5, fontsize=6)
ax.bar_label(rects4, padding=1, fontsize=6)


fig.tight_layout()

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np


labels = ["256", "512", "1024", "2048"]
single_instance = [55989, 86158, 100358, 107866]
two_instance = [60428, 96685, 114396, 118275]
four_instance = [58942, 81894, 103519, 125625]
eigth_instance = [55563, 79373, 107443, 123637]

x = np.arange(len(labels))  # the label locations
width = 0.20  # the width of the bars


fig, ax = plt.subplots()

rects1 = ax.bar(x - width / 2, single_instance, width, label="1 Instance")
rects2 = ax.bar(x + width / 2, two_instance, width, label="2 Instance")
rects3 = ax.bar(x + width * 1.5, four_instance, width, label="4 Instance")
rects4 = ax.bar(x + width * 2.5, eigth_instance, width, label="8 Instance")


# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel("Throughput")
ax.set_xlabel("Batches")
ax.set_title("Impact of TensorRT using number of model instances with batches (gRPC)")
ax.set_xticks(x, labels)
ax.legend()

ax.bar_label(rects1, padding=1, fontsize=6)
ax.bar_label(rects2, padding=6, fontsize=6)
ax.bar_label(rects3, padding=5, fontsize=6)
ax.bar_label(rects4, padding=1, fontsize=6)


fig.tight_layout()

plt.show()

# %% [markdown]
# ### Asynchronous vs non-asynchronous calling

# %%
import matplotlib.pyplot as plt
import numpy as np


labels = ["256", "512", "1024", "2048"]
asynchronous_1 = [152986.47, 166725.03, 205001.92, 264533.04]
non_asynchronous_1 = [58835.11, 95240.29, 111085.70, 121819.45]
asynchronous_2 = [150549.40, 171561.79, 212768.71, 260041.82]
non_asynchronous_2 = [63642.93, 89719.37, 111474.35, 122672.08]
asynchronous_4 = [197985.23, 167694.54, 191942.92, 250979.94]
non_asynchronous_4 = [49733.49, 74167.70, 99910.24, 115764.32]

x = np.arange(len(labels))  # the label locations
width = 0.15  # the width of the bars


fig, ax = plt.subplots()

rects1 = ax.bar(
    x - width / 2, asynchronous_1, width, label="asynchronous-Single instance"
)
rects2 = ax.bar(
    x + width / 2, non_asynchronous_1, width, label="non-asynchronous-Single instance"
)
rects3 = ax.bar(
    x + width * 1.5, asynchronous_2, width, label="asynchronous-2 instances"
)
rects4 = ax.bar(
    x + width * 2.5, non_asynchronous_2, width, label="non-asynchronous-2 instances"
)
rects5 = ax.bar(
    x + width * 3.5, asynchronous_4, width, label="asynchronous-4 instances"
)
rects6 = ax.bar(
    x + width * 4.5, non_asynchronous_4, width, label="non-asynchronous-4 instances"
)


# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel("Throughput (Samples/sec)")
ax.set_xlabel("Batch_size")
ax.set_title(
    "Impact of asynchronous calling VS non-asynchronous Calling using gRPC protocol"
)
ax.set_xticks(x, labels)
ax.legend()

ax.bar_label(rects1, padding=1, fontsize=6)
ax.bar_label(rects2, padding=6, fontsize=6)
ax.bar_label(rects3, padding=5, fontsize=6)
ax.bar_label(rects4, padding=1, fontsize=6)
ax.bar_label(rects5, padding=5, fontsize=6)
ax.bar_label(rects6, padding=1, fontsize=6)


fig.tight_layout()

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np


labels = ["256", "512", "1024", "2048"]
asynchronous_1 = [1, 2, 4, 7]
non_asynchronous_1 = [3, 5, 8, 16]
asynchronous_2 = [1, 3, 4, 7]
non_asynchronous_2 = [3, 5, 9, 16]
asynchronous_4 = [1, 3, 4, 8]
non_asynchronous_4 = [3, 5, 9, 17]

x = np.arange(len(labels))  # the label locations
width = 0.15  # the width of the bars


fig, ax = plt.subplots()

rects1 = ax.bar(
    x - width / 2, asynchronous_1, width, label="asynchronous-Single instance"
)
rects2 = ax.bar(
    x + width / 2, non_asynchronous_1, width, label="non-asynchronous-Single instance"
)
rects3 = ax.bar(
    x + width * 1.5, asynchronous_2, width, label="asynchronous-2 instances"
)
rects4 = ax.bar(
    x + width * 2.5, non_asynchronous_2, width, label="non-asynchronous-2 instances"
)
rects5 = ax.bar(
    x + width * 3.5, asynchronous_4, width, label="asynchronous-4 instances"
)
rects6 = ax.bar(
    x + width * 4.5, non_asynchronous_4, width, label="non-asynchronous-4 instances"
)


# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel("Throughput (Samples/sec)")
ax.set_xlabel("Batch_size")
ax.set_title(
    "Time(Seconds) of asynchronous calling VS non-asynchronous Calling using gRPC protocol"
)
ax.set_xticks(x, labels)
ax.legend()

ax.bar_label(rects1, padding=1, fontsize=6)
ax.bar_label(rects2, padding=6, fontsize=6)
ax.bar_label(rects3, padding=5, fontsize=6)
ax.bar_label(rects4, padding=1, fontsize=6)
ax.bar_label(rects5, padding=5, fontsize=6)
ax.bar_label(rects6, padding=1, fontsize=6)


fig.tight_layout()

plt.show()

# %% [markdown]
# ### Evaluate impact of TensorRT FP32-blocking Vs FP32-asynchronous VS FP16-asynchronous with gRPCC protocol, 4 Instances

# %%
import matplotlib.pyplot as plt
import numpy as np


labels = ["256", "512", "1024", "2048"]
FP32_blocking = [53961.66, 90918.24, 109096.70, 123290.99]
FP32_asynchronous = [162157.80, 175772.14, 206942.92, 259307.05]
FP16_asynchronous = [392754.82, 333653.44, 300409.92, 422990.91]


x = np.arange(len(labels))  # the label locations
width = 0.20  # the width of the bars


fig, ax = plt.subplots()

rects1 = ax.bar(x - width / 2, FP32_blocking, width, label="FP32_blocking")
rects2 = ax.bar(x + width / 2, FP32_asynchronous, width, label="FP32_asynchronous")
rects3 = ax.bar(x + width * 1.5, FP16_asynchronous, width, label="FP16_asynchronous")


# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel("Throughput (Samples/sec)")
ax.set_xlabel("Batch_size")
ax.set_title(
    "Impact of TensorRT FP32-blocking Vs FP32-asynchronous VS FP16-asynchronous with gRPCC protocol,4 instances"
)
ax.set_xticks(x, labels)
ax.legend()

ax.bar_label(rects1, padding=1, fontsize=6)
ax.bar_label(rects2, padding=6, fontsize=6)
ax.bar_label(rects3, padding=5, fontsize=6)


fig.tight_layout()

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np


labels = ["256", "512", "1024", "2048"]
FP32_blocking = [4, 5, 9, 15]
FP32_asynchronous = [1, 3, 4, 7]
FP16_asynchronous = [0, 1, 3, 4]


x = np.arange(len(labels))  # the label locations
width = 0.20  # the width of the bars


fig, ax = plt.subplots()

rects1 = ax.bar(x - width / 2, FP32_blocking, width, label="FP32_blocking")
rects2 = ax.bar(x + width / 2, FP32_asynchronous, width, label="FP32_asynchronous")
rects3 = ax.bar(x + width * 1.5, FP16_asynchronous, width, label="FP16_asynchronous")


# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel("Time (seconds)")
ax.set_xlabel("Batch_size")
ax.set_title(
    "Time(Seconds) of TensorRT FP32-blocking Vs FP32-asynchronous VS FP16-asynchronous with gRPCC protocol,4 instances"
)
ax.set_xticks(x, labels)
ax.legend()

ax.bar_label(rects1, padding=1, fontsize=6)
ax.bar_label(rects2, padding=6, fontsize=6)
ax.bar_label(rects3, padding=5, fontsize=6)


fig.tight_layout()

plt.show()
