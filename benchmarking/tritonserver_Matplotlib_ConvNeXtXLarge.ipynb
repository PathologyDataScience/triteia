# %%
import numpy as np
import matplotlib.pyplot as plt
# include if using a Jupyter notebook
# %matplotlib inline
# Data
Throughput_large = np.array([343.6327591515572, 343.3255050396726, 371.0281922160452, 342.668268744972, 375.2748831931034])
Throughput_small = np.array([524.1329875755295, 518.812206184309, 508.7728420863106, 522.5856042953444, 528.9108571321228])
# steel = np.array([3.3e-5 , 1.2e-5 , 0.9e-5, 1.2e-5, 1.3e-5, 1.6e-5, 1.4e-5, 
#                   1.58e-5, 1.32e-5 , 2.1e-5])

# Calculate the average
Throughput_mean = np.mean(Throughput_large)
Time_mean = np.mean(Throughput_small)
# steel_mean = np.mean(steel)


# Calculate the standard deviation
Throughput_std = np.std(Throughput_large)
Time_std = np.std(Throughput_small)
# steel_std = np.std(steel)


# Define labels, positions, bar heights and error bar heights
labels = ['Throughput_Large(tiles/sec)','Throughput_Small(tiles/sec)',]
x_pos = np.arange(len(labels))
CTEs = [Throughput_mean, Time_mean, ]
error = [Throughput_std, Time_std, ]

# %%
# Build the plot
fig, ax = plt.subplots()
ax.bar(x_pos, CTEs,
       yerr=error,
       align='center',
       alpha=0.5,
       ecolor='black',
       capsize=10)

ax.set_xticks(x_pos)
ax.set_xticklabels(labels)
ax.set_title(r'Throughput Variance for 5 Runs, Model: ConvNeXtXLarge vs convnextsmall'
               "\n" r'GPU:8, Batch size 64, amp')
ax.yaxis.grid(True)

# Save the figure and show
plt.tight_layout()
plt.savefig('bar_plot_with_error_bars.png')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import random

# include if using a Jupyter notebook
# %matplotlib inline
# Data
batch_large_32= np.array([262.94721718488904, 280.8847451906952, 311.73860888423025, 308.18798193254105, 326.41440441397106])
batch_large_64 = np.array([343.6327591515572, 343.3255050396726, 371.0281922160452, 342.668268744972, 375.2748831931034] )
batch_large_128 = np.array([324.28613175660456, 296.50626686397106, 341.8121213160596, 339.5502726442627, 354.7118779090306])
batch_large_256 = np.array([317.2747147498427, 303.7381040748235, 336.6290188370338, 380.7118858798914, 391.52194551647943])
# steel = np.array([3.3e-5 , 1.2e-5 , 0.9e-5, 1.2e-5, 1.3e-5, 1.6e-5, 1.4e-5, 
#                   1.58e-5, 1.32e-5 , 2.1e-5])

# Calculate the average
batch_large_32_mean = np.mean(batch_large_32)
batch_large_64_mean = np.mean(batch_large_64)
batch_large_128_mean = np.mean(batch_large_128)
batch_large_256_mean = np.mean(batch_large_256)

# steel_mean = np.mean(steel)


# Calculate the standard deviation
batch_large_32_std = np.std(batch_large_32)
batch_large_64_std = np.std(batch_large_64)
batch_large_128_std = np.std(batch_large_128)
batch_large_256_std = np.std(batch_large_256)



# Define labels, positions, bar heights and error bar heights
labels = ['batch_32','batch_64','batch_128','batch_256']
label_y = ['Throughput']
x_pos = np.arange(len(labels))
y_pos = np.arange(len("Throughput(tiles/sec)"))
CTEs = [batch_large_32_mean, batch_large_64_mean, batch_large_128_mean, batch_large_256_mean]
error = [batch_large_32_std, batch_large_64_std, batch_large_128_std, batch_large_256_std]

# %%
# Build the plot
fig, ax = plt.subplots()
rgb = (random.random(), random.random(), random.random(),random.random())
print(rgb)
ax.bar(x_pos, CTEs,
       yerr=error,
       align='center',
       alpha=0.5,

       capsize=10)

ax.set_xticks(x_pos)
ax.set_xticklabels(labels)

ax.set_ylabel("Throughput(tiles/sec)")
ax.set_xlabel("Batch size")

ax.set_title(r'Model: ConvNeXtXLarge: Batch size comparison'
               "\n" r'Variance of 5 Runs, Batch size (32,64,128,256)'
               "\n" r' amp, GPU size: (8), Workers: 32, Limit: 10, Instance_group: 1')
ax.yaxis.grid(True)

# Save the figure and show
plt.tight_layout()
plt.savefig('bar_plot_with_error_bars.png')
plt.show()
# Out:
# (0.17190116961558688, 0.8345684590265637, 0.7630589863467176, 0.767986219336851)

# %%
import numpy as np
import matplotlib.pyplot as plt
import random

# include if using a Jupyter notebook
# %matplotlib inline
# Data
batch_small_32= np.array( [409.309308373751, 476.7214733949949, 515.2335417023276, 521.3930237668256, 490.68979352155077],)
batch_small_64 = np.array( [516.7866171024938, 510.442386694202, 510.06382458427197, 494.37373137392893, 523.3974805028695])
batch_small_128 = np.array( [513.1470423443582, 512.0317865420654, 520.5129593572631, 510.57644766295306, 529.9097337093976])
batch_small_256 = np.array([492.49082607860106, 505.18916907958476, 464.88897900250663, 487.1738310061612, 488.04770745278734] )
# steel = np.array([3.3e-5 , 1.2e-5 , 0.9e-5, 1.2e-5, 1.3e-5, 1.6e-5, 1.4e-5, 
#                   1.58e-5, 1.32e-5 , 2.1e-5])

# Calculate the average
batch_small_32_mean = np.mean(batch_small_32)
batch_small_64_mean = np.mean(batch_small_64)
batch_small_128_mean = np.mean(batch_small_128)
batch_small_256_mean = np.mean(batch_small_256)

# steel_mean = np.mean(steel)


# Calculate the standard deviation
batch_small_32_std = np.std(batch_small_32)
batch_small_64_std = np.std(batch_small_64)
batch_small_128_std = np.std(batch_small_128)
batch_small_256_std = np.std(batch_small_256)



# Define labels, positions, bar heights and error bar heights
labels = ['batch_32','batch_64','batch_128','batch_256']
label_y = ['Throughput']
x_pos = np.arange(len(labels))
y_pos = np.arange(len("Throughput(tiles/sec)"))
CTEs = [batch_small_32_mean, batch_small_64_mean, batch_small_128_mean, batch_small_256_mean]
error = [batch_small_32_std, batch_small_64_std, batch_small_128_std, batch_small_256_std]

# %%
# Build the plot
fig, ax = plt.subplots()
rgb = (random.random(), random.random(), random.random(),random.random())
print(rgb)
ax.bar(x_pos, CTEs,
       yerr=error,
       align='center',
       alpha=0.5,

       capsize=10)

ax.set_xticks(x_pos)
ax.set_xticklabels(labels)

ax.set_ylabel("Throughput(tiles/sec)")
ax.set_xlabel("Batch size")

ax.set_title(r'Model: convnextsmall: Batch size comparison'
               "\n" r'Variance of 5 Runs, Batch size (32,64,128,256)'
               "\n" r' amp, GPU size: (8), Workers: 32, Limit: 10, Instance_group: 1')
ax.yaxis.grid(True)

# Save the figure and show
plt.tight_layout()
plt.savefig('bar_plot_with_error_bars.png')
plt.show()
# Out:
# (0.3394883138939424, 0.8093630149549732, 0.20222507624418917, 0.4536317193923304)

# %%
# Workers Comparison For Small Networks

# %%
import numpy as np
import matplotlib.pyplot as plt
import random

# include if using a Jupyter notebook
# %matplotlib inline
# Data
batch_small_16= np.array( [382.88292821277554, 366.8058977461005, 350.8047674529046, 397.29386811902936, 385.7055683383418])
batch_small_32 = np.array([498.06499346886284, 501.71174265394734, 516.5452517599257, 492.17701276309936, 514.5815428919898] )
batch_small_48 = np.array([478.8672162803225, 459.10386185866736, 521.8690319563395, 559.351938591143, 544.9257520058954] )
batch_small_64 = np.array([421.9566284698808, 421.6641002023674, 496.12770274535586, 507.2887534208978, 481.4038056950341] )
# steel = np.array([3.3e-5 , 1.2e-5 , 0.9e-5, 1.2e-5, 1.3e-5, 1.6e-5, 1.4e-5, 
#                   1.58e-5, 1.32e-5 , 2.1e-5])

# Calculate the average
batch_small_32_mean = np.mean(batch_small_16)
batch_small_64_mean = np.mean(batch_small_32)
batch_small_128_mean = np.mean(batch_small_48)
batch_small_256_mean = np.mean(batch_small_64)

# steel_mean = np.mean(steel)


# Calculate the standard deviation
batch_small_32_std = np.std(batch_small_16)
batch_small_64_std = np.std(batch_small_32)
batch_small_128_std = np.std(batch_small_48)
batch_small_256_std = np.std(batch_small_64)



# Define labels, positions, bar heights and error bar heights
labels = ['Workers_16','Workers_32','Workers_48','Workers_64']
label_y = ['Throughput']
x_pos = np.arange(len(labels))
y_pos = np.arange(len("Throughput(tiles/sec)"))
CTEs = [batch_small_32_mean, batch_small_64_mean, batch_small_128_mean, batch_small_256_mean]
error = [batch_small_32_std, batch_small_64_std, batch_small_128_std, batch_small_256_std]

# %%
# Build the plot
fig, ax = plt.subplots()
rgb = (random.random(), random.random(), random.random(),random.random())
print(rgb)
ax.bar(x_pos, CTEs,
       yerr=error,
       align='center',
       alpha=0.5,

       capsize=10)

ax.set_xticks(x_pos)
ax.set_xticklabels(labels)

ax.set_ylabel("Throughput(tiles/sec)")
ax.set_xlabel("Workers")

ax.set_title(r'Model: convnextsmall: Workers comparison'
               "\n" r'Variance of 5 Runs, Worker size (16, 32, 48, 64)'
               "\n" r' amp, GPU size: (8), Workers: 32, Limit: 10, Instance_group: 1')
ax.yaxis.grid(True)

# Save the figure and show
plt.tight_layout()
plt.savefig('bar_plot_with_error_bars.png')
plt.show()
# Out:
# (0.3270134666446616, 0.4394854947424025, 0.44260379172284536, 0.9984778147558852)

# %%
# Workers comparison for Large networks

# %%
import numpy as np
import matplotlib.pyplot as plt
import random

# include if using a Jupyter notebook
# %matplotlib inline
# Data
batch_large_32= np.array( [302.3560595061411, 352.946742791078, 328.0520873221816, 353.59938166165693, 381.48214421619684])
batch_large_64 = np.array( [402.7660204939068, 422.0918652070952, 469.39352690782977, 475.5233821957696, 434.4191134388797])
batch_large_128 = np.array( [379.146154829333, 421.13328078657327, 383.96485531946433, 434.349259966506, 424.87888112020397])
batch_large_256 = np.array( [291.2824650026327, 310.27889967993406, 313.0304390090494, 364.2108892251144, 369.3059081344567])
# steel = np.array([3.3e-5 , 1.2e-5 , 0.9e-5, 1.2e-5, 1.3e-5, 1.6e-5, 1.4e-5, 
#                   1.58e-5, 1.32e-5 , 2.1e-5])

# Calculate the average
batch_large_32_mean = np.mean(batch_large_32)
batch_large_64_mean = np.mean(batch_large_64)
batch_large_128_mean = np.mean(batch_large_128)
batch_large_256_mean = np.mean(batch_large_256)

# steel_mean = np.mean(steel)


# Calculate the standard deviation
batch_large_32_std = np.std(batch_large_32)
batch_large_64_std = np.std(batch_large_64)
batch_large_128_std = np.std(batch_large_128)
batch_large_256_std = np.std(batch_large_256)



# Define labels, positions, bar heights and error bar heights
labels = ['Workers_16','Workers_32','Workers_48','Workers_64']
label_y = ['Throughput']
x_pos = np.arange(len(labels))
y_pos = np.arange(len("Throughput(tiles/sec)"))
CTEs = [batch_large_32_mean, batch_large_64_mean, batch_large_128_mean, batch_large_256_mean]
error = [batch_large_32_std, batch_large_64_std, batch_large_128_std, batch_large_256_std]

# %%
# Build the plot
fig, ax = plt.subplots()
rgb = (random.random(), random.random(), random.random(),random.random())
print(rgb)
ax.bar(x_pos, CTEs,
       yerr=error,
       align='center',
       alpha=0.5,

       capsize=10)

ax.set_xticks(x_pos)
ax.set_xticklabels(labels)

ax.set_ylabel("Throughput(tiles/sec)")
ax.set_xlabel("Workers")

ax.set_title(r'Model: ConvNeXtXLarge: Workers size comparison'
               "\n" r'Variance of 5 Runs, Worker size (16, 32, 48, 64)'
               "\n" r' amp, GPU size: (8), Workers: 32, Limit: 10, Instance_group: 1')
ax.yaxis.grid(True)

# Save the figure and show
plt.tight_layout()
plt.savefig('bar_plot_with_error_bars.png')
plt.show()
# Out:
# (0.7407025882958854, 0.8507643478300501, 0.6439985163520763, 0.14782515864345092)

# %%
#limit Test Small Network

# %%
import numpy as np
import matplotlib.pyplot as plt
import random

# include if using a Jupyter notebook
# %matplotlib inline
# Data
batch_small_2= np.array( [543.2062690266096, 515.5259534322066, 508.74127194557377, 505.3199529561767, 502.6574505815775] )
batch_small_4 = np.array( [535.3871835384556, 500.7567173090054, 526.7158720343465, 512.8793699156279, 505.1200465891581] )
batch_small_6 = np.array([484.89839720117965, 511.28737732766626, 522.4532460466147, 504.64837042402587, 524.2330615521515] )
batch_small_8 = np.array( [509.5816832814914, 519.2701771724762, 509.07366409664684, 513.4227101928604, 495.93190894910305] )
batch_small_10 = np.array( [453.01604231905526, 516.5835117738949, 492.7601010765515, 515.990275062596, 516.1445821978969])
batch_small_20 = np.array( [482.8929544451684, 504.3701534683637, 497.11913701472645, 502.6728759937339, 503.72013826903486])


# Calculate the average
batch_small_32_mean = np.mean(batch_small_2)
batch_small_64_mean = np.mean(batch_small_4)
batch_small_128_mean = np.mean(batch_small_6)
batch_small_256_mean = np.mean(batch_small_8)
batch_small_10_mean = np.mean(batch_small_10)
batch_small_20_mean = np.mean(batch_small_20)

# steel_mean = np.mean(steel)


# Calculate the standard deviation
batch_small_32_std = np.std(batch_small_2)
batch_small_64_std = np.std(batch_small_4)
batch_small_128_std = np.std(batch_small_6)
batch_small_256_std = np.std(batch_small_8)
batch_small_10_std = np.std(batch_small_10)
batch_small_20_std = np.std(batch_small_20)



# Define labels, positions, bar heights and error bar heights
labels = ['Limit_2','Limit_4','Limit_6','Limit_8','Limit_10','Limit_20']
label_y = ['Throughput']
x_pos = np.arange(len(labels))
y_pos = np.arange(len("Throughput(tiles/sec)"))
CTEs = [batch_small_32_mean, batch_small_64_mean, batch_small_128_mean, batch_small_256_mean,batch_small_10_mean,batch_small_20_mean]
error = [batch_small_32_std, batch_small_64_std, batch_small_128_std, batch_small_256_std,batch_small_10_std,batch_small_20_std]

# %%
# Build the plot
fig, ax = plt.subplots()
rgb = (random.random(), random.random(), random.random(),random.random())
print(rgb)
ax.bar(x_pos, CTEs,
       yerr=error,
       align='center',
       alpha=0.5,

       capsize=10)

ax.set_xticks(x_pos)
ax.set_xticklabels(labels)

ax.set_ylabel("Throughput(tiles/sec)")
ax.set_xlabel("Workers")

ax.set_title(r'Model: convnextsmall: Limit comparison'
               "\n" r'Variance of 5 Runs, Limit size (2,4,6,8,10,20)'
               "\n" r' amp, GPU size: (8), Workers: 32, Instance_group: 1')
ax.yaxis.grid(True)

# Save the figure and show
plt.tight_layout()
plt.savefig('bar_plot_with_error_bars.png')
plt.show()
# Out:
# (0.0550222090343786, 0.2814259382632588, 0.8206719213710884, 0.440389951653099)

# %%
# Limit Test Large Netowrk

# %%
import numpy as np
import matplotlib.pyplot as plt
import random

# include if using a Jupyter notebook
# %matplotlib inline
# Data
batch_large_2= np.array( [419.2840241517965, 434.96255475344526, 444.0022286093968, 447.6990446695477, 441.131557255264] )
batch_large_4 = np.array( [424.47604509158805, 427.434693485057, 390.67861868692347, 412.5197387878824, 419.478327566578])
batch_large_6 = np.array([428.3291206587871, 438.42308817308384, 383.76348840284635, 454.8347727505702, 397.8324169367749] )
batch_large_8 = np.array( [429.65269665251816, 464.8473531096713, 430.9793881472564, 455.8616229652723, 410.57657800971606])
batch_large_10 = np.array([430.6158224705674, 452.9942205715936, 427.65545965855165, 430.69409430076223, 435.951065478613] )
batch_large_20 = np.array( [426.4143405038147, 443.1214058914783, 436.0045230421122, 434.55445131053744, 400.6519324520583] )




# Calculate the average
batch_large_32_mean = np.mean(batch_large_2)
batch_large_64_mean = np.mean(batch_large_4)
batch_large_128_mean = np.mean(batch_large_6)
batch_large_256_mean = np.mean(batch_large_8)
batch_large_10_mean = np.mean(batch_large_10)
batch_large_20_mean = np.mean(batch_large_20)

# steel_mean = np.mean(steel)


# Calculate the standard deviation
batch_large_32_std = np.std(batch_large_2)
batch_large_64_std = np.std(batch_large_4)
batch_large_128_std = np.std(batch_large_6)
batch_large_256_std = np.std(batch_large_8)
batch_large_10_std = np.std(batch_large_10)
batch_large_20_std = np.std(batch_large_20)



# Define labels, positions, bar heights and error bar heights
labels = ['Limit_2','Limit_4','Limit_6','Limit_8','Limit_10','Limit_20']
label_y = ['Throughput']
x_pos = np.arange(len(labels))
y_pos = np.arange(len("Throughput(tiles/sec)"))
CTEs = [batch_large_32_mean, batch_large_64_mean, batch_large_128_mean, batch_large_256_mean,batch_large_10_mean,batch_large_20_mean]
error = [batch_large_32_std, batch_large_64_std, batch_large_128_std, batch_large_256_std,batch_large_10_std,batch_large_20_std]

# %%
# Build the plot
fig, ax = plt.subplots()
rgb = (random.random(), random.random(), random.random(),random.random())
print(rgb)
ax.bar(x_pos, CTEs,
       yerr=error,
       align='center',
       alpha=0.5,

       capsize=10)

ax.set_xticks(x_pos)
ax.set_xticklabels(labels)

ax.set_ylabel("Throughput(tiles/sec)")
ax.set_xlabel("Limit")

ax.set_title(r'Model: ConvNeXtXLarge: Limit comparison'
               "\n" r'Variance of 5 Runs, Limit size (2,4,6,8,10,20)'
               "\n" r' amp, GPU size: (8), Workers: 32, Instance_group: 1')
ax.yaxis.grid(True)

# Save the figure and show
plt.tight_layout()
plt.savefig('bar_plot_with_error_bars.png')
plt.show()
# Out:
# (0.3918028162218842, 0.5068704445778028, 0.31628060876615627, 0.5666903905704348)

# %%
#intance group Small Network

# %%
import numpy as np
import matplotlib.pyplot as plt
import random

# include if using a Jupyter notebook
# %matplotlib inline
# Data
batch_small_1= np.array([492.598292516457, 487.02715725330273, 508.3259909749937, 519.5132134859771, 514.6994977869292] )
batch_small_2 = np.array( [370.6148971278426, 449.6279997282951, 509.2550178261932, 497.9752183937966, 513.6229785332771])
batch_small_3 = np.array([363.2260882689781, 462.3017265447134, 458.3757499902973, 513.8199485683094, 516.9529016669524] ) 


# Calculate the average
batch_small_32_mean = np.mean(batch_small_1)
batch_small_64_mean = np.mean(batch_small_2)
batch_small_128_mean = np.mean(batch_small_3)

# steel_mean = np.mean(steel)


# Calculate the standard deviation
batch_small_32_std = np.std(batch_small_1)
batch_small_64_std = np.std(batch_small_2)
batch_small_128_std = np.std(batch_small_3)




# Define labels, positions, bar heights and error bar heights
labels = ['Instance_group_1','Instance_group_2','Instance_group_3']
label_y = ['Instance_group']
x_pos = np.arange(len(labels))
y_pos = np.arange(len("Throughput(tiles/sec)"))
CTEs = [batch_small_32_mean, batch_small_64_mean, batch_small_128_mean]
error = [batch_small_32_std, batch_small_64_std, batch_small_128_std]

# %%
# Build the plot
fig, ax = plt.subplots()
rgb = (random.random(), random.random(), random.random(),random.random())
print(rgb)
ax.bar(x_pos, CTEs,
       yerr=error,
       align='center',
       alpha=0.5,

       capsize=10)

ax.set_xticks(x_pos)
ax.set_xticklabels(labels)

ax.set_ylabel("Throughput(tiles/sec)")
ax.set_xlabel("Instance Group ")

ax.set_title(r'Model: ConvNeXtXLarge: Instance Group comparison'
               "\n" r'Variance of 5 Runs, GPU_count (1,2,3), Limit size (10)'
               "\n" r' amp, GPU size: (8), Workers: 32, Instance_group: 1')
ax.yaxis.grid(True)

# Save the figure and show
plt.tight_layout()
plt.savefig('bar_plot_with_error_bars.png')
plt.show()
# Out:
# (0.11404539895575427, 0.8620798692136228, 0.07169451676946281, 0.07083608848488865)

# %%
#intance group Large Network

# %%
import numpy as np
import matplotlib.pyplot as plt
import random

# include if using a Jupyter notebook
# %matplotlib inline
# Data
batch_large_1= np.array([450.077983932562, 419.63211802651466, 462.2642211773125, 437.48421677197837, 430.9164897850986] )
batch_large_2 = np.array([370.9949354088576, 306.08566279607254, 346.5624365225137, 339.02522220196033, 386.54112289488575] )
batch_large_3 = np.array([351.8226184261554, 340.6972111180688, 319.7135801632044, 346.52950793481705, 364.65294539507266] ) 


# Calculate the average
batch_large_32_mean = np.mean(batch_large_1)
batch_large_64_mean = np.mean(batch_large_2)
batch_large_128_mean = np.mean(batch_large_3)

# steel_mean = np.mean(steel)


# Calculate the standard deviation
batch_large_32_std = np.std(batch_large_1)
batch_large_64_std = np.std(batch_large_2)
batch_large_128_std = np.std(batch_large_3)




# Define labels, positions, bar heights and error bar heights
labels = ['Instance_group_1','Instance_group_2','Instance_group_3']
label_y = ['Instance_group']
x_pos = np.arange(len(labels))
y_pos = np.arange(len("Throughput(tiles/sec)"))
CTEs = [batch_large_32_mean, batch_large_64_mean, batch_large_128_mean]
error = [batch_large_32_std, batch_large_64_std, batch_large_128_std]

# %%
# Build the plot
fig, ax = plt.subplots()
rgb = (random.random(), random.random(), random.random(),random.random())
print(rgb)
ax.bar(x_pos, CTEs,
       yerr=error,
       align='center',
       alpha=0.5,

       capsize=10)

ax.set_xticks(x_pos)
ax.set_xticklabels(labels)

ax.set_ylabel("Throughput(tiles/sec)")
ax.set_xlabel("Limit")

ax.set_title(r'Model: ConvNeXtXLarge: Instance Group comparison'
               "\n" r'Variance of 5 Runs, GPU_count (1,2,3), Limit size (10)'
               "\n" r' amp, GPU size: (8), Workers: 32, Instance_group: 1')
ax.yaxis.grid(True)

# Save the figure and show
plt.tight_layout()
plt.savefig('bar_plot_with_error_bars.png')
plt.show()
# Out:
# (0.08346272894405404, 0.592331000921222, 0.003508783068969179, 0.4814309749530089)

# %%
# Large Network Vs Small Network - Throughput

# %%
import numpy as np
import matplotlib.pyplot as plt
# include if using a Jupyter notebook
# %matplotlib inline
# Data
throughput_elapsed_large = np.array([454.5268459116172, 449.72996252376737, 428.7192847320921, 406.15891850595216, 432.9786108868255])
throughput_elapsed_small = np.array([435.54582042390973, 513.7599490972764, 505.03672580030315, 513.9928478181233, 517.3619232690235] )
# steel = np.array([3.3e-5 , 1.2e-5 , 0.9e-5, 1.2e-5, 1.3e-5, 1.6e-5, 1.4e-5, 
#                   1.58e-5, 1.32e-5 , 2.1e-5])

# Calculate the average
throughput_elapsed_large_mean = np.mean(throughput_elapsed_large)
throughput_elapsed_small_mean = np.mean(throughput_elapsed_small)
# steel_mean = np.mean(steel)


# Calculate the standard deviation
throughput_elapsed_large_std = np.std(throughput_elapsed_large)
throughput_elapsed_small_std = np.std(throughput_elapsed_small)
# steel_std = np.std(steel)


# Define labels, positions, bar heights and error bar heights
labels = ['throughput_large(Tiles/sec)','throughput_small(Tiles/sec)']
x_pos = np.arange(len(labels))
CTEs = [throughput_elapsed_large_mean, throughput_elapsed_small_mean]
error = [throughput_elapsed_large_std,throughput_elapsed_small_std]

# %%
# Build the plot
fig, ax = plt.subplots()
ax.bar(x_pos, CTEs,
       yerr=error,
       align='center',
       alpha=0.5,
       ecolor='black',
       capsize=10)

ax.set_xticks(x_pos)
ax.set_xticklabels(labels)

ax.set_ylabel("Throughput(tiles/sec)")
ax.set_xlabel("Models")
ax.set_title(r'Throughput Variance for 5 Runs, Model: ConvNeXtXLarge vs convnextsmall'
              "\n" r'GPU:8, Batch size 64, amp')
ax.yaxis.grid(True)

# Save the figure and show
plt.tight_layout()
plt.savefig('bar_plot_with_error_bars.png')
plt.show()

# %%
# Large Network Vs Small Network - Time elapsed

# %%
import numpy as np
import matplotlib.pyplot as plt
# include if using a Jupyter notebook
# %matplotlib inline
# Data
Time_elapsed_large = np.array([16.331388235092163, 16.346003770828247, 15.125535249710083, 16.377355337142944, 14.954371452331543])
Time_elapsed_small = np.array([10.7071692943573,   10.816925764083862, 11.030414819717407,   10.738856315612793,  10.610427379608154])
# steel = np.array([3.3e-5 , 1.2e-5 , 0.9e-5, 1.2e-5, 1.3e-5, 1.6e-5, 1.4e-5, 
#                   1.58e-5, 1.32e-5 , 2.1e-5])

# Calculate the average
Time_elapsed_large_mean = np.mean(Time_elapsed_large)
Time_elapsed_small_mean = np.mean(Time_elapsed_small)
# steel_mean = np.mean(steel)


# Calculate the standard deviation
Time_elapsed_large_std = np.std(Time_elapsed_large)
Time_elapsed_small_std = np.std(Time_elapsed_small)
# steel_std = np.std(steel)


# Define labels, positions, bar heights and error bar heights
labels = ['Time_elapsed_Large (sec)','Time_elapsed_Small (sec)']
x_pos = np.arange(len(labels))
CTEs = [Time_elapsed_large_mean, Time_elapsed_small_mean]
error = [Time_elapsed_large_std,Time_elapsed_small_std]

# %%
# Build the plot
fig, ax = plt.subplots()
ax.bar(x_pos, CTEs,
       yerr=error,
       align='center',
       alpha=0.5,
       ecolor='black',
       capsize=10)

ax.set_xticks(x_pos)
ax.set_xticklabels(labels)

ax.set_ylabel("Time elapsed (sec)")
ax.set_xlabel("Models")
ax.set_title(r'Time elapsed Variance for 5 Runs, Model: ConvNeXtXLarge vs convnextsmall'
              "\n" r'GPU:8, Batch size 64, amp')
ax.yaxis.grid(True)

# Save the figure and show
plt.tight_layout()
plt.savefig('bar_plot_with_error_bars.png')
plt.show()

# %%
# Comparison of no acceleration, amp, and trt-FP16 with Muliple Workers and GPUs, ConvNeXtLarge Model, Batch size 64 |  5,062 tiles, 224 by 224 by 3, no overlap.

# %%
import matplotlib.pyplot as plt
import numpy as np


labels = ["Workers= 16", "Workers = 32", "Workers = 48", "Workers = 64",  "Workers = 128"]

# No_acceleration = [184.8628170332371, 176.18249313480652, 167.11798777408703,  145.01916024007505, 136.15503933346366]
amp = [243.25134437086538, 231.34907586702312, 209.68866384728005, 194.6193757635381, 168.0194599750842  ]
# TensorRT_FP16 = [23.40064629229974, 26.765010565195873, 22.914557136706126, 20.401154522497244, 18.78040153084365]


x = np.arange(len(labels))  # the label locations
width = 0.20  # the width of the bars


fig, ax = plt.subplots()



rects2 = ax.bar(x + width / 2, amp, width, label="workers")




# Add some text for labels, title and custom x-axis tick labels, etc.

ax.set_ylabel("Throughput(tiles/sec)")
ax.set_xlabel("Workers")
ax.set_title(r"Comparison with Workers (16,32,48,64), ConvNeXtLarge  Model"
            #  "\n" r"with Multi-Workers (16,32,48,64), ConvNeXtLarge  Model"
              "\n" r"Batch size 64, GPU 8, 5,062 tiles, 224 by 224 by 3, no overlap.")
ax.set_xticks(x, labels)

ax.legend()

# ax.bar_label(rects1, padding=5, fontsize=5)
ax.bar_label(rects2, padding=5, fontsize=5)
# ax.bar_label(rects3, padding=5, fontsize=5)


fig.tight_layout()
ax.grid(axis='y')
ax.set_axisbelow(True)
plt.show()

# %%
# Throughput for amp with Muliple Instances and Multi-GPU, ConvNeXt Large Model, Batch size 64 |  5,062 tiles, 224 by 224 by 3, no overlap.

# %%
import matplotlib.pyplot as plt
import numpy as np



labels = ["GPU = 2", "GPU = 4", "GPU = 6", "GPU = 8"]
Instance_1 = [ 142.20350206126028, 192.04946557334895, 225.5913262587506,  223.25035336413623 ]
Instance_2 = [ 169.69497215714293, 221.273110329534525, 220.93792952594848,  257.4182147445336]
Instance_3 = [ 164.4829523146244, 211.08456220028023, 249.63469722981228,  249.32256119012013]


x = np.arange(len(labels))  # the label locations
width = 0.20  # the width of the bars


fig, ax = plt.subplots()


rects1 = ax.bar(x - width / 2, Instance_1, width, label="Instance_1")
rects2 = ax.bar(x + width / 2, Instance_2, width, label="Instance_2")
rects3 = ax.bar(x + width * 1.5, Instance_3, width, label="Instance_3")



# Add some text for labels, title and custom x-axis tick labels, etc.

ax.set_ylabel("Throughput(tiles/sec)")
ax.set_xlabel("Instances")
ax.set_title(r"Comparison of Multi-Instance in amp with No of GPUs (2,4,6,8), ConvNeXt Large Model"
              "\n" r"Batch size 64, 5,062 tiles, 224 by 224 by 3, no overlap.")
ax.set_xticks(x, labels)

ax.legend()

ax.bar_label(rects1, padding=5, fontsize=5)
ax.bar_label(rects2, padding=5, fontsize=5)
ax.bar_label(rects3, padding=5, fontsize=5)


fig.tight_layout()
ax.grid(axis='y')
ax.set_axisbelow(True)
plt.show()

# %% [markdown]
# # Throughput for amp with Muliple Batch sizes and Multi-GPU, ConvNeXt Large Model, 5,062 tiles, 224 by 224 by 3, no overlap.

# %%
import matplotlib.pyplot as plt
import numpy as np



labels = ["2", "4", "6", "8"]
batch_32 = [150.99992850441114, 249.815141986798, 262.8966893364064, 266.3288498478577]
batch_64= [ 138.58355853972904, 224.45885937027796, 228.79640649491816, 257.1284348578849]
batch_128 =  [126.96461509429759, 170.42963417944196, 220.5136517570566, 227.82245747160258]
batch_192 = [ 91.5914842051223, 144.84974379550937, 217.18870113272826, 205.16955552968346]
batch_256 = [  85.42571068903084 , 128.7748718104202, 163.14422124720855, 187.3364550830969 ]




x = np.arange(len(labels))  # the label locations
width = 0.17  # the width of the bars


fig, ax = plt.subplots()


rects1 = ax.bar(x - width / 2, batch_32, width, label="Batch = 32")
rects2 = ax.bar(x + width / 2, batch_64, width, label="atch = 64")
rects3 = ax.bar(x + width * 1.5, batch_128, width, label="Batch = 128")
rects4 = ax.bar(x + width * 2.5, batch_192, width, label="Batch = 192")
rects5 = ax.bar(x + width * 3.5, batch_256, width, label="Batch = 256")



# Add some text for labels, title and custom x-axis tick labels, etc.

ax.set_ylabel("Throughput(tiles/sec)")
ax.set_xlabel("GPU")
ax.set_title(r"Throughput for amp with Muliple Batch sizes and Multi-GPU (2,4,6,8), ConvNeXt Large Model"
              "\n" r"5,062 tiles, 224 by 224 by 3, no overlap.")
ax.set_xticks(x, labels)

ax.legend()

ax.bar_label(rects1, padding=1, fontsize=6)
ax.bar_label(rects2, padding=6, fontsize=6)
ax.bar_label(rects3, padding=5, fontsize=6)
ax.bar_label(rects4, padding=1, fontsize=6)
ax.bar_label(rects5, padding=1, fontsize=6)


fig.tight_layout()
ax.grid(axis='y')
ax.set_axisbelow(True)
plt.show()

# %% [markdown]
# # Comparison of no acceleration, amp, and trt-FP16  with No of GPUs (2,4,6,8), ConvNeXt Large Model

# %%
import matplotlib.pyplot as plt
import numpy as np


# labels = ["No-acceleration", "AMP", "TensorRT-FP16"]
# batch_gpu2 = [ 78.1082063687742, 112.62640624248264, 66.32086024317843 ]
# batch_gpu4 = [110.31538176455784, 165.0852533608288, 100.69193758121875]
# batch_gpu6 = [145.22682476688556, 185.74065686605675, 129.79788698803762]
# batch_gpu8 = [124.02337632615179, 216.09572469313767, 144.3481056753241]

labels = ["GPU = 2", "GPU = 4", "GPU = 6", "GPU = 8"]
# No_acceleration = [ 78.1082063687742, 145.22682476688556, 66.32086024317843,  124.02337632615179]
# amp = [ 112.62640624248264, 165.0852533608288, 185.74065686605675, 216.09572469313767]
# TensorRT_FP16 = [66.32086024317843, 100.69193758121875, 129.79788698803762, 150.249378599934891 ]
No_acceleration = [82.47294170772251, 118.5136774234802,168.36559050459613, 164.72037516028678   ]
amp = [ 138.58355853972904, 224.45885937027796, 228.79640649491816, 257.1284348578849]
TensorRT_FP16 = [41.66490382602174,33.13263075068169,31.806496744570904,24.902592828709626 ]


x = np.arange(len(labels))  # the label locations
width = 0.20  # the width of the bars


fig, ax = plt.subplots()


rects1 = ax.bar(x - width / 2, No_acceleration, width, label="No_acceleration")
rects2 = ax.bar(x + width / 2, amp, width, label="AMP")
rects3 = ax.bar(x + width * 1.5, TensorRT_FP16, width, label="TensorRT_FP16")



# Add some text for labels, title and custom x-axis tick labels, etc.

ax.set_ylabel("Throughput(tiles/sec)")
ax.set_xlabel("Acceleration")
ax.set_title(r"Comparison of no acceleration, amp, and trt-FP16" 
             "\n" r"with GPUs (2,4,6,8), ConvNeXt Large Model"
              "\n" r"Batch size 64, 5,062 tiles, 224 by 224 by 3, no overlap.")
ax.set_xticks(x, labels)

ax.legend()

ax.bar_label(rects1, padding=1, fontsize=6)
ax.bar_label(rects2, padding=6, fontsize=6)
ax.bar_label(rects3, padding=5, fontsize=6)


fig.tight_layout()
ax.grid(axis='y')
ax.set_axisbelow(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np



labels = ["GPU = 2", "GPU = 4", "GPU = 6", "GPU = 8"]
batch_limit2 = [147.90012244733106, 196.0135980198145, 203.77257692595404, 204.38313109113537 ]
batch_limit4 = [135.75974583208165, 174.5738961985014, 206.7471461484155,204.31660872696025]
batch_limit6 = [155.11559327322115, 216.96826707263264, 233.39149684330883 , 239.91323785095722 ]
batch_limit8 = [152.97044333835686, 221.3742462664734, 222.53521712756313, 244.70215820038592 ]
batch_limit10 = [153.63827530515675, 216.91046448918735, 252.75861643957987, 231.51324683689228]


x = np.arange(len(labels))  # the label locations
width = 0.16  # the width of the bars


fig, ax = plt.subplots()


rects1 = ax.bar(x - width / 2, batch_limit2, width, label="Limit = 2")
rects2 = ax.bar(x + width / 2, batch_limit4, width, label="Limit = 4")
rects3 = ax.bar(x + width * 1.5, batch_limit6, width, label="Limit = 6")
rects4 = ax.bar(x + width * 2.5, batch_limit8, width, label="Limit = 8")
rects5 = ax.bar(x + width * 3.5, batch_limit10, width, label="Limit = 10")



# Add some text for labels, title and custom x-axis tick labels, etc.

ax.set_ylabel("Throughput(tiles/sec)")
ax.set_xlabel("GPU")
ax.set_title(r"Comparison of Limit (1-10) for AMP with No of GPUs (2,4,6,8), ConvNeXt Large Model"
              "\n" r"Batch size 128, 5,062 tiles, 224 by 224 by 3, no overlap.")
ax.set_xticks(x, labels)

ax.legend()

ax.bar_label(rects1, padding=1, fontsize=6)
ax.bar_label(rects2, padding=6, fontsize=6)
ax.bar_label(rects3, padding=5, fontsize=6)
ax.bar_label(rects4, padding=6, fontsize=6)
ax.bar_label(rects5, padding=1, fontsize=6)


fig.tight_layout()
ax.grid(axis='y')
ax.set_axisbelow(True)
plt.show()
